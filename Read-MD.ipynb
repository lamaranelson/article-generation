# %%
import markdown
from IPython.core.display import HTML


with open('path-to/Life_in_the_Amazon_jungle/Unveiling_the_Mysteries__A_Glimpse_into_Life_in_the_Amazon_Jungle.md', 'r') as f:
    text = f.read()

html = markdown.markdown(text)

HTML(html)
# Out:
# <div style="text-align: center;"><img src="data:image/png;base64,..." alt="Header Image" /></div>
#
# <p>"Unveiling the Mysteries: A Glimpse into Life in the Amazon Jungle"</p>
# <p>Have you ever pondered about life in the Amazon Jungle? Not a fleeting visit, but a permanent existence amidst the lush greenery, the symphony of wildlife, and the constant reminder of the wild? If so, you're in for an enlightening journey. This article aims to transport you to the heart of the Amazon, offering a peek into the distinctive lifestyle that characterizes this region. </p>
# ...
